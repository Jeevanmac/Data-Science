# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
files = files.upload()
# Out:
#      <input type="file" id="files-cecbb70e-3ecd-48ae-8c91-51a44a83076c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cecbb70e-3ecd-48ae-8c91-51a44a83076c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
glass = pd.read_csv('glass.csv')
glass
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %% [markdown]
# # EDA

# %%
glass.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
glass.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
glass.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 209    False
# 210    False
# 211    False
# 212    False
# 213    False
# Length: 214, dtype: bool

# %%
glass[glass.duplicated()]
# Out:
#          RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 39  1.52213  14.21  3.82  0.47  71.77  0.11  9.57  0.0  0.0     1

# %%
glass[glass.duplicated()].shape
# Out:
# (1, 10)

# %%
glass['Type'].value_counts().sort_index(ascending=True)
# Out:
# 1    70
# 2    76
# 3    17
# 5    13
# 6     9
# 7    29
# Name: Type, dtype: int64

# %% [markdown]
# # Visualization

# %%
features = glass.columns[:-1].tolist()
for feat in features:
    skew = glass[feat].skew()
    sns.distplot(glass[feat], kde= False, label='Skew = %.3f' %(skew), bins=30)
    plt.legend(loc='best')
    plt.show()
# Out:
# <ipython-input-13-825ab55f13cb>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(glass[feat], kde= False, label='Skew = %.3f' %(skew), bins=30)

# %%
g_df = glass.copy()

# %%
fig, axes=plt.subplots(9,1,figsize=(14,12),sharex=False,sharey=False)
sns.boxplot(x='RI',data=g_df,palette='crest',ax=axes[0]);
sns.boxplot(x='Na',data=g_df,palette='crest',ax=axes[1]);
sns.boxplot(x='Mg',data=g_df,palette='crest',ax=axes[2]);
sns.boxplot(x='Al',data=g_df,palette='crest',ax=axes[3]);
sns.boxplot(x='Si',data=g_df,palette='crest',ax=axes[4]);
sns.boxplot(x='K',data=g_df,palette='crest',ax=axes[5]);
sns.boxplot(x='Ca',data=g_df,palette='crest',ax=axes[6]);
sns.boxplot(x='Ba',data=g_df,palette='crest',ax=axes[7]);
sns.boxplot(x='Fe',data=g_df,palette='crest',ax=axes[8]);
plt.tight_layout(pad=2.0);
# Out:
# <ipython-input-18-0c62329d5709>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='RI',data=g_df,palette='crest',ax=axes[0]);
# <ipython-input-18-0c62329d5709>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Na',data=g_df,palette='crest',ax=axes[1]);
# <ipython-input-18-0c62329d5709>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Mg',data=g_df,palette='crest',ax=axes[2]);
# <ipython-input-18-0c62329d5709>:5: FutureWarning:
#
# ...

# %%
plt.figure(figsize=(8,8))
sns.pairplot(glass,hue ='Type', palette='coolwarm')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.heatmap(glass.corr(), annot=True, fmt='.1g', cmap="viridis", cbar=False, linewidths=0.5, linecolor='blue')
# Out:
# <Axes: >

# %%
plt.figure(figsize = (16,9))
ax = sns.barplot(x = glass['Type'].value_counts().index.tolist(), y = glass['Type'].value_counts().tolist())
plt.yticks(rotation = 0, fontsize = 20)
plt.xticks(rotation = 45, fontsize = 20)
plt.title("Class Type Distribution",  fontsize = 28, fontweight = 'bold')
plt.xlabel('Types',fontsize=20)
plt.ylabel('Counts',fontsize=20)
for i in ax.containers:
    ax.bar_label(i,)

# %%
x = glass.drop('Type',axis=1)
y=glass[['Type']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=0)

# %%
x_train,y_train
# Out:
# (          RI     Na    Mg    Al     Si     K     Ca   Ba    Fe
#  111  1.52739  11.02  0.00  0.75  73.08  0.00  14.96  0.0  0.00
#  159  1.51796  13.50  3.36  1.63  71.94  0.57   8.81  0.0  0.09
#  24   1.51720  13.38  3.50  1.15  72.85  0.50   8.43  0.0  0.00
#  30   1.51768  12.65  3.56  1.30  73.08  0.61   8.69  0.0  0.14
#  60   1.51905  13.60  3.62  1.11  72.64  0.14   8.76  0.0  0.00
#  ..       ...    ...   ...   ...    ...   ...    ...  ...   ...
#  67   1.52152  13.05  3.65  0.87  72.32  0.19   9.85  0.0  0.17
#  192  1.51623  14.20  0.00  2.79  73.46  0.04   9.04  0.4  0.09
#  117  1.51708  13.72  3.68  1.81  72.06  0.64   7.88  0.0  0.00
#  47   1.52667  13.99  3.70  0.71  71.57  0.02   9.82  0.0  0.10
#  172  1.51321  13.00  0.00  3.02  70.70  6.21   6.93  0.0  0.00
#
#  [149 rows x 9 columns],
#       Type
#  111     2
#  159     3
#  24      1
#  30      1
#  60      1
#  ..    ...
#  67      1
#  192     7
#  117     2
#  47      1
#  172     5
#
# ...

# %%
x_test,y_test
# Out:
# (          RI     Na    Mg    Al     Si     K     Ca    Ba    Fe
#  197  1.51727  14.70  0.00  2.34  73.28  0.00   8.95  0.66  0.00
#  37   1.51797  12.74  3.48  1.35  72.96  0.64   8.68  0.00  0.00
#  89   1.51640  12.55  3.48  1.87  73.23  0.63   8.08  0.00  0.09
#  176  1.51905  14.00  2.39  1.56  72.37  0.00   9.57  0.00  0.00
#  170  1.52369  13.44  0.00  1.58  72.22  0.32  12.24  0.00  0.00
#  ..       ...    ...   ...   ...    ...   ...    ...   ...   ...
#  157  1.52121  14.03  3.76  0.58  71.79  0.11   9.65  0.00  0.00
#  8    1.51918  14.04  3.58  1.37  72.08  0.56   8.30  0.00  0.00
#  40   1.51793  12.79  3.50  1.12  73.03  0.64   8.77  0.00  0.00
#  129  1.52020  13.98  1.35  1.63  71.76  0.39  10.56  0.00  0.18
#  13   1.51748  12.86  3.56  1.27  73.21  0.54   8.38  0.00  0.17
#
#  [65 rows x 9 columns],
#       Type
#  197     7
#  37      1
#  89      2
#  176     6
#  170     5
#  ..    ...
#  157     3
#  8       1
#  40      1
#  129     2
#  13      1
#
# ...

# %% [markdown]
# # Standardization

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
k_values = np.arange(1,25)
train_accuracy = []
test_accuracy = []

# %%
from sklearn.neighbors import KNeighborsClassifier
for i, k in enumerate(k_values):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train,y_train)
    train_accuracy.append(knn.score(x_train, y_train))
    test_accuracy.append(knn.score(x_test, y_test))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
plt.figure(figsize=[13,8])
plt.plot(k_values, test_accuracy, label = 'Testing Accuracy')
plt.plot(k_values, train_accuracy, label = 'Training Accuracy')
plt.legend()
plt.title('-value VS Accuracy')
plt.xlabel('Number of Neighbors',fontsize=20)
plt.ylabel('Accuracy',fontsize=20)
plt.xticks(k_values)
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train, y_train)
y_pred_KNeighborsClassifier = knn.predict(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.metrics import accuracy_score
scores = []
cv_scores = []
score = accuracy_score(y_pred_KNeighborsClassifier,y_test)
scores.append(score)
score_knn=cross_val_score(knn, x,y, cv=10)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
score_knn.std()
# Out:
# 0.13418097908195592

# %%
score_knn.std()*2
# Out:
# 0.26836195816391184

# %%
score_knn.mean()
# Out:
# 0.6454545454545455

# %%
cv_score = score_knn.mean()

# %%
cv_scores.append(cv_score)

# %%
cv_scores
# Out:
# [0.6454545454545455]

# %%
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(y_test, y_pred_KNeighborsClassifier), annot=True, cmap = 'viridis', fmt='.0f')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (9,9)
_, ax = plt.subplots()
ax.hist(y_test, color = 'm', alpha = 0.5, label = 'actual', bins=7)
ax.hist(y_pred_KNeighborsClassifier, color = 'c', alpha = 0.5, label = 'prediction', bins=7)
ax.yaxis.set_ticks(np.arange(0,30))
ax.legend(loc = 'best')
plt.show()
