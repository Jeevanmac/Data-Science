# %% [markdown]
# ### Topics: Descriptive Statistics and Probability

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-43372169-afb7-4e61-8589-9416da73d328" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-43372169-afb7-4e61-8589-9416da73d328">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df11 = pd.read_csv('NEw33 - Sheet1.csv')

# %%
df11.head()
# Out:
#     Name of company Measure X
# 0     Allied Signal    24.23%
# 1     Bankers Trust    25.53%
# 2     General Mills    25.41%
# 3    ITT Industries    24.14%
# 4  J.P.Morgan & Co.    29.62%

# %%
kk = df['Measure X']

# %%
df = pd.DataFrame(kk)
df['Measure X'] = df['Measure X'].str.rstrip('%').astype(float)
df['Measure X'] = df['Measure X'].astype(int)

print(df['Measure X'])
# Out:
# 0     24
# 1     25
# 2     25
# 3     24
# 4     29
# 5     28
# 6     25
# 7     24
# 8     40
# 9     32
# 10    91
# 11    25
# 12    39
# 13    26
# 14    35
# Name: Measure X, dtype: int64

# %%
m_x=pd.Series(df['Measure X'])

# %%
Q1 = np.quantile(m_x,0.25)
Q3 = np.quantile(m_x,0.75)
med = np.median(m_x)
IQR = Q3 - Q1
upper_bound = Q3+(1.5*IQR)
lower_bound = Q1-(1.5*IQR)
print('First Quantile=', Q1, 'Second Quantile=', med, 'Third Quantile=', Q3,
      'Inter-Quartile Range=', IQR, 'Upper Whisker=', upper_bound, 'Lower Whisker=', lower_bound)
Outliers = m_x[(m_x <= lower_bound) | (m_x >= upper_bound)]
print('The outlier in the boxplot:',Outliers)
Outliers = m_x[(m_x >= upper_bound)]
print('The outlier in the boxplot:',Outliers)
print(m_x.describe())
print("Variance=",m_x.var())
# Out:
# First Quantile= 25.0 Second Quantile= 26.0 Third Quantile= 33.5 Inter-Quartile Range= 8.5 Upper Whisker= 46.25 Lower Whisker= 12.25
# The outlier in the boxplot: 10    91
# Name: Measure X, dtype: int64
# The outlier in the boxplot: 10    91
# Name: Measure X, dtype: int64
# count    15.000000
# mean     32.800000
# std      16.992435
# min      24.000000
# 25%      25.000000
# 50%      26.000000
# 75%      33.500000
# max      91.000000
# Name: Measure X, dtype: float64
# Variance= 288.74285714285713

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df['Measure X'])
plt.title('Box plot of Measure X')
plt.ylabel('Values')
plt.show()

# %%
plt.figure(figsize = (10,9))
ax = sns.barplot(y = m_x, x = df11['Name of company'], edgecolor='black')
plt.xticks(rotation = 90, fontsize = 12, fontweight = 'bold')
for i in ax.containers:
    ax.bar_label(i,)
plt.show()
